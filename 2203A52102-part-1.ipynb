# %%
#Part 1 – Implement Basic Data Structures using Numpy, Pandas

import numpy as np
lst=[11,22,33,44]
arr=np.array(lst)
print("list=",lst)
print("array=",arr)
print("type=",type(arr))
print("type=",type(lst))
# Out:
# list= [11, 22, 33, 44]
# array= [11 22 33 44]
# type= <class 'numpy.ndarray'>
# type= <class 'list'>

# %%
import numpy as np
arr1=(11,22,33,44)
arr2=(11,22,33,44)
mul=np.multiply(arr1,arr2)
print(mul)
div=np.divide(arr1,arr2)
print(div)
pow=np.power(arr1,arr2)
print(pow)
# Out:
# [ 121  484 1089 1936]
# [1. 1. 1. 1.]
# [        285311670611  4981753131911086080 -4053175462519618527
#                     0]

# %%
result= arr1 + arr2

# Create a textual output
output_text = f"Addition of Two Arrays:\narray1 + array2 = {result}"

# Print the result
print(output_text)
# Out:
# Addition of Two Arrays:
# array1 + array2 = (11, 22, 33, 44, 11, 22, 33, 44)

# %%
ans=np.sin(45)
print(ans)
ans=np.cos(45)
print(ans)
ans=np.log(45)
print(ans)
ans=np.exp(45)
print(ans)
# Out:
# 0.8509035245341184
# 0.5253219888177297
# 3.8066624897703196
# 3.4934271057485095e+19
